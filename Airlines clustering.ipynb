# %% [markdown]
# Perform (hierarchical, K means & db-scan clustering) for the airlines data to obtain optimum number of clusters

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import  normalize

# %%
#import datasets
airline=pd.read_excel("E:\Data sciences notes\Assignment\Clustering\EastWestAirlines.xlsx",sheet_name="data")
airline.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
airline.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
airline_norm = norm_func(airline.iloc[:,1:])
airline_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
trans = MinMaxScaler()
data0 = pd.DataFrame(trans.fit_transform(airline.iloc[:,1:]))
data0
# Out:
#             0    1     2    3    4         5         6         7         8   \
# 0     0.016508  0.0  0.00  0.0  0.0  0.000660  0.011628  0.000000  0.000000
# 1     0.011288  0.0  0.00  0.0  0.0  0.000815  0.023256  0.000000  0.000000
# 2     0.024257  0.0  0.00  0.0  0.0  0.015636  0.046512  0.000000  0.000000
# 3     0.008667  0.0  0.00  0.0  0.0  0.001896  0.011628  0.000000  0.000000
# 4     0.057338  0.0  0.75  0.0  0.0  0.164211  0.302326  0.067398  0.075472
# ...        ...  ...   ...  ...  ...       ...       ...       ...       ...
# 3994  0.010837  0.0  0.00  0.0  0.0  0.032330  0.046512  0.006490  0.018868
# 3995  0.037766  0.0  0.00  0.0  0.0  0.003720  0.058140  0.000000  0.000000
# 3996  0.043169  0.0  0.50  0.0  0.0  0.096505  0.093023  0.000000  0.000000
# 3997  0.032202  0.0  0.00  0.0  0.0  0.001896  0.011628  0.016225  0.018868
# 3998  0.001769  0.0  0.00  0.0  0.0  0.000000  0.000000  0.000000  0.000000
#
#             9    10
# 0     0.843742  0.0
# ...

# %%
#create Dendrogram
plt.figure(figsize=(15,7))
dendrogram = sch.dendrogram(sch.linkage(airline_norm, method='ward'))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
plt.show()

# %%
# Create Clusters
hc = AgglomerativeClustering(n_clusters=5, linkage='complete',affinity = "euclidean").fit(airline_norm)
cluster_labels=pd.Series(hc.labels_)
cluster_labels
# creating a new column and assigning it to new column 
airline['cluster_H']=cluster_labels
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline.iloc[:,1:].groupby(airline.cluster_H).mean()
# Out:
#                  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# cluster_H
# 0           59968.433667   88.883768   1.712224   1.000401   1.011222
# 1          157084.578462  208.673846   4.661538   1.000000   1.061538
# 2           80173.963287  248.550699   2.104895   1.009615   1.000874
# 3          131999.500000  347.000000   2.500000   1.000000   1.000000
# 4           45515.064516   32.258065   1.000000   2.483871   1.000000
#
#             Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# cluster_H
# 0          10271.530261     9.105812         227.797194         0.656112
# 1          70477.086154    23.249231        1019.433846         3.196923
# 2          16882.864510    13.412587         739.958916         2.236888
# 3          65634.250000    69.250000       19960.000000        49.250000
# 4          14618.870968    16.129032         443.225806         1.967742
#
#            Days_since_enroll    Award?  cluster_H
# cluster_H
# ...

# %%
for i in range(0,11):
    plt.figure(figsize=(12, 7))
    sns.barplot(y=airline.iloc[:,i],x=airline["cluster_H"])
    plt.xlabel("Cluster_H")
    plt.ylabel(airline.columns[i])
    plt.title("hierarchical Clustering")
    plt.show()

# %% [markdown]
# #k-mean

# %%
#import libraries
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
#import datasets
df=pd.read_excel("E:\Data sciences notes\Assignment\Clustering\EastWestAirlines.xlsx",sheet_name="data")
df.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
# Normalize heterogenous numerical data by using Standard Scaler
df_norm=StandardScaler().fit_transform(df.iloc[:,1:])
df_norm
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
# within-cluster sum-of-squares criterion 
wcss=[]
for i in range (1,11):
    kmeans=KMeans(n_clusters=i,random_state=2)
    kmeans.fit(df_norm)
    wcss.append(kmeans.inertia_)

# %%
# Plot K values range vs WCSS to get Elbow graph for choosing K (no. of clusters)
plt.plot(range(1,11),wcss)
plt.title('Elbow Graph')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Cluster algorithm using K=5
clusters_K=KMeans(5,random_state=42).fit(df_norm)
clusters_K
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
clusters_K.labels_
# Out:
# array([1, 1, 1, ..., 3, 1, 1])

# %%
# Assign clusters to the data set
airline_K=df.copy()
airline_K['clusters_K']=clusters_K.labels_
airline_K
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
# Compute the centroids for K=4 clusters with 11 variables
clusters_K.cluster_centers_
# Out:
# array([[ 1.13984539,  1.05672065,  0.09776869, -0.09824189, -0.06276658,
#          0.57151541,  1.51103346,  3.44127553,  3.6610428 ,  0.27107706,
#          0.88975067],
#        [-0.29035586, -0.05818754, -0.59651518, -0.09824189, -0.06074586,
#         -0.51420592, -0.49040819, -0.18783605, -0.19980876, -0.20213465,
#         -0.34539972],
#        [-0.04688966, -0.1562356 , -0.66822727,  9.03825361, -0.06276658,
#         -0.10166533,  0.61785114,  0.0875494 ,  0.22034681, -0.07246398,
#          0.05178388],
#        [ 0.43260424, -0.01954084,  1.22083157, -0.09824189, -0.05447771,
#          0.94096329,  0.75568144, -0.09151819, -0.10212979,  0.37689814,
#          0.58013031],
#        [ 0.63971926, -0.08443292,  1.0220844 , -0.09824189, 15.64629931,
#          3.17969131,  1.71461374,  0.03329269,  0.05969539,  0.23987261,
#          0.33752735]])

# %%
# Group data by Clusters (K=4)
airline_K.groupby('clusters_K').agg(['mean']).reset_index()
# Out:
#   clusters_K          ID#        Balance  Qual_miles cc1_miles cc2_miles  \
#                      mean           mean        mean      mean      mean
# 0          0  1731.100000  188455.641176  961.558824  2.194118  1.000000
# 1          1  2237.743286   44293.077409   98.530806  1.237362  1.000000
# 2          2  2269.372093   68876.581395   23.255814  1.139535  2.348837
# 3          3  1593.586764  117119.906376  130.094431  3.736077  1.000000
# 4          4  1664.866667  138061.400000   78.800000  3.466667  1.000000
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.000000  30945.770588   26.111765       5277.958824       15.258824
# 1  1.000395   4722.390205    6.885861        196.838468        0.614929
# 2  1.000000  14689.837209   17.534884        582.627907        2.209302
# 3  1.001614  39793.209040   18.843422        332.092010        0.987086
# ...

# %%
airline_K
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline_K['clusters_K'].value_counts()
# Out:
# 1    2532
# 3    1239
# 0     170
# 2      43
# 4      15
# Name: clusters_K, dtype: int64

# %%
clusters_K.inertia_
# Out:
# 23707.163884815604

# %%
wcss
# Out:
# [43989.000000000095,
#  35409.51662986136,
#  30899.253324696245,
#  27161.524991470334,
#  24541.329582045753,
#  21480.03433584088,
#  19880.826282129,
#  17316.753604356454,
#  16049.684338633037,
#  14732.229882347452]

# %%
# Plot Clusters
for i in range(0,11):
    plt.figure(figsize=(12, 7))  
    sns.barplot(y=airline_K.iloc[:,i],x=airline_K['clusters_K'])
    plt.title("kmeans clustering")
    plt.ylabel(airline_K.columns[i])
    plt.xlabel('kmeans')
    plt.show()

# %% [markdown]
# #dbscan

# %%
#Import the libraries
import sklearn
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn import metrics
import seaborn as sns

# %%
#import datasets
data1=pd.read_excel("E:\Data sciences notes\Assignment\Clustering\EastWestAirlines.xlsx",sheet_name="data")
data1.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
def standardize(x):
    x = (x-x.mean())/((x.std()))
    return x
data = standardize(data1.iloc[:,1:])
data.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0 -0.451084   -0.186275  -0.769482   -0.09823  -0.062759    -0.702698
# 1 -0.539389   -0.186275  -0.769482   -0.09823  -0.062759    -0.701001
# 2 -0.319991   -0.186275  -0.769482   -0.09823  -0.062759    -0.539185
# 3 -0.583726   -0.186275  -0.769482   -0.09823  -0.062759    -0.689200
# 4  0.239648   -0.186275   1.409295   -0.09823  -0.062759     1.082986
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0    -1.103926          -0.328562        -0.362123           1.395280
# 1    -0.999801          -0.328562        -0.362123           1.379784
# 2    -0.791550          -0.328562        -0.362123           1.411744
# 3    -1.103926          -0.328562        -0.362123           1.372037
# 4     1.499207           1.154788         0.692404           1.363805
#
#      Award?
# 0 -0.766823
# 1 -0.766823
# 2 -0.766823
# 3 -0.766823
# 4  1.303755

# %%
dbscan = DBSCAN(eps=5,min_samples=13)
dbscan.fit(data)
# Out:
# DBSCAN(eps=5, min_samples=13)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
data['cluster']=dbscan.labels_
data.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0 -0.451084   -0.186275  -0.769482   -0.09823  -0.062759    -0.702698
# 1 -0.539389   -0.186275  -0.769482   -0.09823  -0.062759    -0.701001
# 2 -0.319991   -0.186275  -0.769482   -0.09823  -0.062759    -0.539185
# 3 -0.583726   -0.186275  -0.769482   -0.09823  -0.062759    -0.689200
# 4  0.239648   -0.186275   1.409295   -0.09823  -0.062759     1.082986
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0    -1.103926          -0.328562        -0.362123           1.395280
# 1    -0.999801          -0.328562        -0.362123           1.379784
# 2    -0.791550          -0.328562        -0.362123           1.411744
# 3    -1.103926          -0.328562        -0.362123           1.372037
# 4     1.499207           1.154788         0.692404           1.363805
#
#      Award?  cluster
# 0 -0.766823        0
# 1 -0.766823        0
# 2 -0.766823        0
# 3 -0.766823        0
# ...

# %%
data.groupby('cluster').agg(['mean']).reset_index()
# Out:
#   cluster   Balance Qual_miles cc1_miles  cc2_miles cc3_miles Bonus_miles  \
#                mean       mean      mean       mean      mean        mean
# 0      -1  1.920700   0.546122  0.656137  -0.098230  9.232507    2.568892
# 1       0 -0.012686  -0.002043  0.002803  -0.098230 -0.062759   -0.016541
# 2       1 -0.212054  -0.100105 -0.769482  13.447294 -0.062759    0.135217
# 3       2  0.041600  -0.186275 -0.613855   6.674532 -0.062759   -0.228547
#
#   Bonus_trans Flight_miles_12mo Flight_trans_12 Days_since_enroll    Award?
#          mean              mean            mean              mean      mean
# 0    2.282075          2.770287        2.654994          0.198981  0.613562
# 1   -0.022443         -0.019995       -0.020656         -0.000574 -0.004783
# 2    0.763388          0.166126        0.481498         -0.020835  0.061408
# 3    0.539766          0.045438        0.080402         -0.100109  0.046618

# %%
metrics.silhouette_score(data,dbscan.labels_)
# Out:
# 0.5614974240799168

# %%
data['cluster'].value_counts()
# Out:
#  0    3929
#  2      28
# -1      27
#  1      15
# Name: cluster, dtype: int64

# %%
for i in range(0,12):
    plt.figure(figsize=(12, 7))
    sns.barplot(y=data.iloc[:,i],x=data["cluster"])
    plt.xlabel("DBSCAN Cluster")
    plt.ylabel(data.columns[i])
    plt.title("DBSCAN Cluster")
    plt.show()
